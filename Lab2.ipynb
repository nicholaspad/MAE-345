# %% [markdown]
# # Part I: Testing out the Crazyflie (15 Pts)
#
# We will first assemble and configure the Crazyflie and run a simple test script to make sure everything is functioning before doing the lab.
#
# **If you received an unbuilt drone kit**: First, assemble your Crazyflie. Instructions are located [here](https://www.bitcraze.io/documentation/tutorials/getting-started-with-crazyflie-2-x/). **There is one caveat you should be aware of, however.** Instead of using the short connector pins, you need to use the longer set. This is because we are using the FlowDeck expansion deck, which will provide us with significantly more accurate state measurements. There are instructions for mounting expansion decks on the Crazyflie [here](https://www.bitcraze.io/documentation/tutorials/getting-started-with-expansion-decks/). We suggest you push the pins down until they appear on the other side of the flow deck to ensure a secure connection (the pins can be slid further through the black plastic on the connector but it may take some physical effort). Next, we need to install a few things so that you can set the radio channel your crazyflie uses.
#
# **If you received a pre-built drone**: Please carefully read the instructions for building the drone [here](https://www.bitcraze.io/documentation/tutorials/getting-started-with-crazyflie-2-x/). Even though you have a pre-built drone, the instructions contain a lot of useful information about working with the drone (e.g., the correct configuration of propellers, how to attach the battery, how to switch the drone on/off, the meaning of different LED patterns, etc.).
#
# Ensure that you have activated the mae345 conda environment. Then, follow the instructions for your operating system below. Note: Using a Mac (without the M1 chips) is probably the easiest option of the options. For this lab, prioritize setting up at least one person in your group with the software for running the Crazyflie. If you are able to get multiple laptops setup, that's great (but not critical at this stage in the course!).
#
# **Linux**
#
# `pip install cflib libusb cfclient`
#
# Linux only: Update the UDEV rules to recognize the Crazyflie Radio by following the instructions at the end of this [page](https://github.com/bitcraze/crazyflie-lib-python/blob/master/docs/installation/install.md). After completing them, you may need to reboot your computer.
#
# **Windows**
#
# Follow all installation instructions [here](https://github.com/bitcraze/crazyradio-firmware/blob/master/docs/building/usbwindows.md). You should repeat the driver installation twice: first with the Crazyflie connected by USB, then again with the radio receiver connected.
#
# `pip install cflib libusb cfclient`
#
# **Mac (without the Apple M1 chip)**
#
# These instructions are for Macs with Intel chips (i.e., before Apple moved to the M1 chip). See below for instructions for newer Macs with the M1 chip. If you are unsure what kind of chip your Mac has, click on the Apple logo on the top left of your desktop, click on "About this Mac" and see what kind of chip is listed (Intel or M1).
#
# Now, make sure you have the `brew` package manager installed. You can check if it is already installed by running `brew help` in your terminal. If you see some output, then continue to the next step. If brew is not installed, install it using the terminal command [here](https://brew.sh/).
#
# Next, in your terminal, run:
#
# `brew install libusb`
#
# Then, run the following (make sure that you are running this from the mae345 conda environment):
#
# `pip install cflib libusb cfclient`
#
# **Mac (with the Apple M1 chip)**
#
# These instructions are for newer Macs that use the Apple M1 chip. We will first need to install a version of the `brew` package manager that is capable of installing software designed for Intel chips.
#
# In your terminal, run the following commands:
#
# `cd ~/Downloads
# mkdir homebrew
# curl -L https://github.com/Homebrew/brew/tarball/master | tar xz --strip 1 -C homebrew`
#
# This creates a directory called `homebrew` in your Downloads folder and downloads homebrew. Now run the following:
#
# `sudo mv homebrew /usr/local/homebrew`
#
# Open up the ~/.zshrc file by running:
#
# `open ~/.zshrc`
#
# Then add the following to the end of that file:
#
# `export PATH=$HOME/bin:/usr/local/bin:$PATH
# export PATH=$HOME/bin:/usr/local/bin:$PATH
# alias axbrew='arch -x86_64 /usr/local/homebrew/bin/brew'
# `
#
# Save the file, close it, and then restart the terminal (you will have to activate the mae345 conda environment again). Now we can use the command `axbrew` to install software designed for Intel chips.
#
# Run the following:
#
# `axbrew install libusb`
#
# Finally, run the following (make sure you're running this from the conda environment):
#
# `pip install cfclient`
#
#
# **After installing these packages:** Run `cfclient` in terminal (Mac) or Anaconda Prompt (Windows). For Linux, run the command `python -m cfclient.gui` in terminal and make sure your drone is on. If you receive an error regarding `pysdl2`, install the required packages as described [here](https://github.com/bitcraze/crazyflie-clients-python/issues/592) based on your operating system (`pip install pysdl2 pysdl2-dll`).
#
# The `cfclient` software is a GUI for interacting with the Crazyflie. Connect the Crazyflie to your computer by USB and turn it on. Then, hit `Scan` in the upper left of the window and from the drop down menu pick `usb://0` and hit `Connect`. This uses the USB interface to connect to the drone. In the console tab (hit `View -> Tabs -> Console` if it isn't present), you should see `Crazyflie 2.1 is up and running!` followed by other information.
#
# The last thing we have to do is set the radio channel the Crazyflie will operate on and will prevent other groups from sending commands to your drone (or your commands to their drone). Hit `Connect -> Configure 2.X`. Set the radio channel option in the dialog box that appears to **Ch.\<your group number\>**. Also make sure that the radio bandwith is 2 MBit/s (if it's set to something else, change it to 2 MBit/s). Hit `Write` (if you don't, this won't be saved). Now, change the value of the variable in the cell below to your group number.

# %%
group_number = 2

# %% [markdown]
# Next, disconnect the Crazyflie from the USB and plug in the CrazyRadio, hit the `Disconnect` button and `Scan` again. You should see an address that looks something like `radio://0/<group_number>/2M`. You don't need to connect to it again, and, in fact, you can't command the drone via Python while it's connected to the GUI. However, you should confirm the address exists.
#
# To check that everything is working properly, run the following cell. It will print a bunch of logging information (specifically the roll, pitch, and yaw of the drone).
#
# Some tips for working with the Crazyflie:
# - The connection with the drone is not always the most stable. Sometimes, a glitch occurs and you may need to restart the drone and / or Jupyter. To restart Jupyter, open the terminal where you ran `jupyter notebook` and hit `Ctrl + C` followed by `y` and `ENTER`.
# - Sometimes the drone gets a poor initialization before flying. If it crashes before stabilizing at the hover point, it is unlikely your code is wrong. You may need to just run it again. It helps to plug in the battery/powering the drone on when it is flat on a surface.
# - **Turn the quadrotor on when it is plugged in to charge it!** It will not charge when it is powered off so that the onboard processor can monitor the battery and prevent it from overcharging.
# - See [this page](https://github.com/Princeton-Introduction-to-Robotics/F2022/blob/main/crazyflie-tips.md) for a compilation of useful tips.

# %%
# This is an example from the Crazyflie Python API.
# See https://github.com/bitcraze/crazyflie-lib-python/blob/master/examples/basiclogSync.py

import logging
import time

import cflib.crtp
from cflib.crazyflie import Crazyflie
from cflib.crazyflie.log import LogConfig
from cflib.crazyflie.syncCrazyflie import SyncCrazyflie
from cflib.crazyflie.syncLogger import SyncLogger

# Only output errors from the logging framework
logging.basicConfig(level=logging.ERROR)


# Initialize the low-level drivers (don't list the debug drivers)
cflib.crtp.init_drivers(enable_debug_driver=False)
# Scan for Crazyflies and use the first one found
print('Scanning interfaces for Crazyflies...')
available = cflib.crtp.scan_interfaces()
print('Crazyflies found:')
for i in available:
    print(i[0])

if len(available) == 0:
    print('No Crazyflies found, cannot run example')
else:
    lg_stab = LogConfig(name='Stabilizer', period_in_ms=10)
    lg_stab.add_variable('stabilizer.roll', 'float')
    lg_stab.add_variable('stabilizer.pitch', 'float')
    lg_stab.add_variable('stabilizer.yaw', 'float')

    cf = Crazyflie(rw_cache='./cache')
    with SyncCrazyflie(available[0][0], cf=cf) as scf:
        with SyncLogger(scf, lg_stab) as logger:
            endTime = time.time() + 10

            for log_entry in logger:
                timestamp = log_entry[0]
                data = log_entry[1]
                logconf_name = log_entry[2]

                print('[%d][%s]: %s' % (timestamp, logconf_name, data))

                if time.time() > endTime:
                    break
# Out:
# Scanning interfaces for Crazyflies...
# Crazyflies found:
# radio://0/2/2M
# radio://0/2/2M
# [19558][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19568][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19578][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19588][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19598][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19608][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19618][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19628][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19638][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19648][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19658][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19668][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19678][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19688][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19698][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19708][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19718][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19728][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19738][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19748][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19758][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19768][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19778][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19788][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19798][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19808][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19818][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19828][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19838][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19848][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19858][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19868][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19878][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19888][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19898][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19908][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19918][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19928][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19938][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19948][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19958][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19968][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19978][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19988][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [19998][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20008][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20018][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20028][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20038][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20048][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20058][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20068][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20078][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20088][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20098][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20108][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20118][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20128][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20138][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20148][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20158][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20168][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20178][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20188][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20198][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20208][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20218][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20228][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20238][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20248][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20258][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20268][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20278][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20288][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20298][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20308][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20318][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20328][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20338][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20348][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20358][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20368][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20378][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20388][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20398][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20408][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20418][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20428][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20438][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20448][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20458][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20468][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20478][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20488][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20498][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20508][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20518][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20528][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20538][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20548][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20558][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20568][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20578][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20588][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20598][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20608][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20618][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20628][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20638][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20648][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20658][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20668][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20678][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20688][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20698][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20708][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20718][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20728][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20738][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20748][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20758][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20768][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20778][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20788][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20798][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20808][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20818][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20828][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20838][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20848][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20858][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20868][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20878][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20888][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20898][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20908][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20918][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20928][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20938][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20948][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20958][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20968][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20978][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20988][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [20998][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21008][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21018][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21028][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21038][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21048][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21058][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21068][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21078][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21088][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21098][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21108][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21118][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21128][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21138][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21148][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21158][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21168][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21178][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21188][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21198][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21208][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21218][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21228][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21238][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21248][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21258][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21268][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21278][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21288][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21298][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21308][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21318][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21328][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21338][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21348][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21358][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21368][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21378][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21388][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21398][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21408][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21418][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21428][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21438][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21448][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21458][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21468][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21478][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21488][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21498][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21508][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21518][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21528][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21538][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21548][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21558][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21568][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21578][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21588][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21598][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21608][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21618][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21628][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21638][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21648][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21658][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21668][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21678][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21688][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21698][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21708][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21718][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21728][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21738][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21748][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21758][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21768][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21778][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21788][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21798][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21808][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21818][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21828][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21838][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21848][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21858][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21868][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21878][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21888][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21898][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21908][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21918][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21928][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21938][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21948][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21958][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21968][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21978][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21988][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [21998][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22008][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22018][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22028][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22038][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22048][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22058][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22068][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22078][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22088][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22098][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22108][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22118][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22128][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22138][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22148][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22158][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22168][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22178][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22188][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22198][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22208][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22218][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22228][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22238][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22248][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22258][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22268][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22278][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22288][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22298][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22308][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22318][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22328][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22338][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22348][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22358][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22368][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22378][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22388][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22398][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22408][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22418][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22428][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22438][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22448][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22458][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22468][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22478][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22488][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22498][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22508][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22518][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22528][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22538][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22548][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22558][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22568][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22578][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22588][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22598][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22608][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22618][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22628][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22638][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22648][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22658][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22668][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22678][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22688][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22698][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22708][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22718][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22728][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22738][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22748][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22758][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22768][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22778][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22788][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22798][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22808][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22818][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22828][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22838][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22848][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22858][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22868][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22878][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22888][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22898][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22908][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22918][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22928][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22938][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22948][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22958][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [22968][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# ...
# [28428][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28438][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28448][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28458][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28468][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28478][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28488][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28498][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28508][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28518][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28528][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28538][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28548][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28558][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28568][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28578][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28588][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28598][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28608][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28618][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28628][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28638][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28648][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28658][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28668][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28678][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28688][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28698][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28708][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28718][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28728][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28738][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28748][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28758][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28768][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28778][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28788][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28798][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28808][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28818][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28828][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28838][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28848][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28858][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28868][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28878][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28888][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28898][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28908][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28918][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28928][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28938][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28948][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28958][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28968][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28978][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28988][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [28998][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29008][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29018][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29028][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29038][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29048][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29058][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29068][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29078][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29088][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29098][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29108][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29118][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29128][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29138][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29148][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29158][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29168][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29178][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29188][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29198][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29208][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29218][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29228][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29238][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29248][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29258][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29268][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29278][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29288][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29298][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29308][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29318][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29328][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29338][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29348][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29358][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29368][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29378][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29388][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29398][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29408][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29418][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29428][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29438][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29448][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29458][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29468][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29478][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29488][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29498][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29508][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29518][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29528][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29538][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29548][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}
# [29558][<cflib.crazyflie.log.LogConfig object at 0x7fa370b9cb50>]: {'stabilizer.roll': 0.0, 'stabilizer.pitch': 0.0, 'stabilizer.yaw': 0.0}

# %% [markdown]
# # Part II: LQR Control of a Quadrotor
#
# In this part, we are going to use a hover state linearization of the quadrotor, like you wrote in the previous lab to allow the quadrotor to hover. First, we are going to import the various classes and functions we need.

# %%
from quad_utils import plotting, Crazyflie as CF, animate_quad
import matplotlib.pyplot as plt
import numpy as np
import scipy
from scipy.linalg import solve_continuous_are, inv
from IPython.display import HTML, Image

# %% [markdown]
# ## Problem 1 (20 Pts)
#
# Now, in the cell below, you will fillout the function that will actually solve the LQR problem. That is, given the matrices $\mathbf{A}, \mathbf{B}, \mathbf{Q}, \mathbf{R}$, you should compute the $K$ that minimizes the LQR cost function. You are encouraged to use the function `scipy.linalg.solve_continuous_are` to solve the CARE. Also, we use the convention that the stabilizing control input is given by $\mathbf{u} = \mathbf{K}\mathbf{x}$ (as opposed to $\mathbf{u} = -\mathbf{K}\mathbf{x}$).

# %%
def lqr(A: np.ndarray, B: np.ndarray, Q: np.ndarray, R: np.ndarray) -> np.ndarray:
    S = scipy.linalg.solve_continuous_are(A, B, Q, R)
    K = -scipy.linalg.inv(R).dot(B.T).dot(S)
    return K

# %% [markdown]
# ## Problem 2 (30 Pts)
#
# Finally, you will use all the code you have written thus far to actually stabilize your Crazyflie. The following code implements a version of the Crazyflie class from our `quad_utils` library that uses the linearization and LQR functions you just wrote. This class is useful as it provides simulation and animation functionality to verify your controller is working. It also saves out $\mathbf{K}$ so it can be loaded onto the actual quadrotor for control. You will need to adjust the gains yourself, but we filled in a few for you to get started.

# %% [markdown]
# ### LQR Simulation
#
# The code for this problem is broken into two sections: designing the LQR controller and running the Crazyflie.
#
# The following cell uses the `lqr` function you just wrote in conjunction with our implementation of the linearization function from the previous lab (here as `self.hover_state_linearization()`) to create an instance of the `CrazyflieLQR` class. The details of this process are not important, but this class provides a lot of functionality for designing the LQR controller. It also saves the $\mathbf{K}$ matrix out as `quad_data/lqr_gains.npy`. Run this block to set your gains.

# %%
class CrazyflieLQR(CF):
    def __init__(self, Q: np.ndarray, R: np.ndarray, hover_pos: np.ndarray):
        super().__init__()
        self._hover_pos = hover_pos
        self._hover_state = np.concatenate([self._hover_pos, np.zeros(9)])
        A, B =  self.hover_state_linearization()
        self._K = lqr(A, B, Q, R)
        
        print('Using K matrix:')
        print()
        print(self._K)
        
        np.save('quad_data/lqr_gains', self._K)
        
    @property
    def K(self) -> np.ndarray:
        return self._K
    
    def controller(self, state: np.ndarray, t: float) -> np.ndarray:
        return self._K @ (state - self._hover_state) + np.array([self.mass * self.gravity, 0, 0, 0])

# The first argument is the Q matrix, the second is the R matrix. You can disregard the third argument.
quad = CrazyflieLQR(np.diag([10000, 10000, 2000, 0.001, 0.001, 1, 120, 120, 1, 0.005, 0.005, 1]), 2 * np.diag([1e5, 6e9, 6e9, 1e4]), np.zeros(3))
# Out:
# Using K matrix:
#
# [[ 1.59211500e-13 -0.00000000e+00 -1.00000000e-01 -0.00000000e+00
#   -1.70244093e-13 -0.00000000e+00  8.74029329e-14 -0.00000000e+00
#   -7.74919351e-02 -0.00000000e+00  4.34459018e-14 -0.00000000e+00]
#  [-0.00000000e+00 -9.12870929e-04 -0.00000000e+00 -1.25289957e-03
#   -0.00000000e+00 -5.18430219e-19 -0.00000000e+00 -4.93371491e-04
#   -0.00000000e+00 -1.88594087e-04 -0.00000000e+00 -1.33376196e-19]
#  [ 9.12870929e-04 -0.00000000e+00  5.18051963e-15 -0.00000000e+00
#   -1.24838543e-03 -0.00000000e+00  4.92518468e-04 -0.00000000e+00
#    1.54183767e-15 -0.00000000e+00 -1.87556448e-04 -0.00000000e+00]
#  [-0.00000000e+00 -4.04012450e-13 -0.00000000e+00 -3.79237894e-13
#   -0.00000000e+00 -7.07106781e-03 -0.00000000e+00 -1.85106319e-13
#   -0.00000000e+00 -3.81925637e-14 -0.00000000e+00 -7.10074653e-03]]

# %% [markdown]
# This next cell simulates the quadrotor flying with a random initial condition for five seconds and plots some of the states. You should see the system stabilize for most choices of the random initial conditions, or your gains will almost certainly not work on the real Crazyflie. Feel free to change the plotted variables.

# %%
# Uncomment the following line if you want to use the same random initial condition.
# np.random.seed(0)

ic = np.random.rand(12) * 1.2
ic[0:3] = ic[0:3] / 5
ic[6:9] = ic[6:9] / 5

times, states, inputs = quad.simulate(ic, 5, 0.01, clip_input=False)

#%matplotlib notebook
plt.rcParams["figure.figsize"] = (16,8)
fig = plt.figure()

ax = fig.add_subplot(121, title='Position')
ax.plot(times, states[0, :], label='x')
ax.plot(times, states[1, :], label='y')
ax.plot(times, states[2, :], label='z')
ax.legend()

ax = fig.add_subplot(122, title='Angles')
ax.plot(times, states[3, :], label='phi')
ax.plot(times, states[4, :], label='theta')
ax.plot(times, states[5, :], label='psi')
ax.legend()

# %% [markdown]
# This cell optionally animates the simulation data computed and plotted in the previous cell.

# %%
animate_quad(0.1, states).save('./anim.gif', writer='pillow', fps=100)
Image(url='./anim.gif')
# Out:
# <img src="./anim.gif"/>

# %% [markdown]
# ## Running the Quadrotor
#
# ### Setup
#
# Now that you have a set of LQR gains you are happy with trying out, it's time to put them on the quadrotor. First, you need to flash the quadrotor with our modified version of the Crazyflie's firmware. Our modifications apply the LQR control law in real time --- i.e. much faster than we could do with Python over the radio.
#
# **You only need to do this successfully once AND if you have a new drone.** If you have a pre-built drone, the drone has the correct firmware on it already. First, power the drone off. Then, hold the power switch down for about 3 seconds until the blue LED flashes, then release. After releasing, two blue LEDs should be flashing.  Then, open up your terminal and enter the following commands:
#
# ```
# cd firmware-precompiled
# python3 -m cfloader flash cf2.bin stm32-fw
# ```
#
# (**Note**: You should make sure that there are no other drones powered on in the vicinity of your drone. Otherwise the firmware update is likely to fail due to interference from other drones.)
#
# Once this is completed, your Crazyflie should restart and play a jingle. If all the lights are on, not flashing, and no jingle plays, repeat the flashing process.
#
# ### Flying
#
# To test out the quadrotor, simply run the cells below after placing it in the netted area. The drone will take off and land using the Crazyflie's own PID controller, but your LQR controller will stabilize the drone once it is hover a half meter off the ground. The drone beeps when switching controllers.
#
# If you seen an error about something missing in the Log TOC (e.g. `stabilizer.controller not in param TOC`), this most likely means your computer lost connection with the drone midflight. (**Warning**: When you are testing your LQR controller, it can cause intereference with other drones' LQR controller. The LQR only runs for 5 seconds, so we recommend staggering the use of the following cell with other groups that are in same drone testing area to avoid interference issues.)
#
# ### Submission
#
# You must submit the following to confirm that you got the drone to hover successfully:
# - A video of your drone hovering
# - The file `quad_data/quad_traj.npz`
# - This notebook file
#
# Please submit a zip file containing these to Gradescope, **HW2: Coding**.
#
# You will be graded according to the data in `quad_data/quad_traj.npz`, which is plotted below. The rubric is the following:
# - If tracking error in x and y each below 75 cm: 10 points
# - If tracking error in x and y each below 50 cm: 20 points
# - If tracking error in x and y each below 25 cm: 30 points

# %% [markdown]
# When you are ready to test on the Crazyflie, set your gains in the next cell, then run the following cell.

# %%
# SET GAINS HERE
Q = np.diag([10000, 10000, 2000, 0.001, 0.001, 1, 120, 120, 1, 0.005, 0.005, 1])
R = 2 * np.diag([1e5, 6e9, 6e9, 1e4])
quad = CrazyflieLQR(Q, R, np.zeros(3)) # TO START, COPY AND PASTE YOUR COST MATRICES Q AND R FROM ABOVE
# Out:
# Using K matrix:
#
# [[ 1.59211500e-13 -0.00000000e+00 -1.00000000e-01 -0.00000000e+00
#   -1.70244093e-13 -0.00000000e+00  8.74029329e-14 -0.00000000e+00
#   -7.74919351e-02 -0.00000000e+00  4.34459018e-14 -0.00000000e+00]
#  [-0.00000000e+00 -9.12870929e-04 -0.00000000e+00 -1.25289957e-03
#   -0.00000000e+00 -5.18430219e-19 -0.00000000e+00 -4.93371491e-04
#   -0.00000000e+00 -1.88594087e-04 -0.00000000e+00 -1.33376196e-19]
#  [ 9.12870929e-04 -0.00000000e+00  5.18051963e-15 -0.00000000e+00
#   -1.24838543e-03 -0.00000000e+00  4.92518468e-04 -0.00000000e+00
#    1.54183767e-15 -0.00000000e+00 -1.87556448e-04 -0.00000000e+00]
#  [-0.00000000e+00 -4.04012450e-13 -0.00000000e+00 -3.79237894e-13
#   -0.00000000e+00 -7.07106781e-03 -0.00000000e+00 -1.85106319e-13
#   -0.00000000e+00 -3.81925637e-14 -0.00000000e+00 -7.10074653e-03]]

# %%
import logging
import random
import time
import numpy as np

import cflib.crtp
from cflib.crazyflie import Crazyflie
from cflib.crazyflie.syncCrazyflie import SyncCrazyflie
from cflib.crazyflie.log import LogConfig
from cflib.crazyflie.syncLogger import SyncLogger

URI = f'radio://0/{group_number}/2M'

# Only output errors from the logging framework
logging.basicConfig(level=logging.ERROR)

log_keys = ['e_x',
            'e_y',
            'e_roll',
            'e_pitch',
            'u2_pwm',
            'u3_pwm',]

other_log_keys = []

if __name__ == '__main__':
    cflib.crtp.init_drivers(enable_debug_driver=False)

    with SyncCrazyflie(URI, cf=Crazyflie(rw_cache='./cache')) as scf:
        cf = scf.cf

        lg_stab = LogConfig(name='LQR', period_in_ms=10)
        lg_data = {}

        for key in log_keys:
            lg_stab.add_variable('ctrlLQR.' + key, 'float')
            lg_data[key] = []

        for key in other_log_keys:
            lg_stab.add_variable( key, 'float')
            lg_data[key.split('.')[1]] = []

        for i in range(4):
            for j in range(12):
                cf.param.set_value(f'ctrlLQR.k{i + 1}{j + 1}', '{:.10f}'.format(quad.K[i, j]))

        print('Loaded LQR gain matrix.')
        print('Initializing as PID')
        cf.param.set_value('stabilizer.controller', '1')

        cf.param.set_value('kalman.resetEstimation', '1')
        time.sleep(0.1)
        cf.param.set_value('kalman.resetEstimation', '0')
        time.sleep(2)

        print('Reset Kalman filter.')
        print('Taking off!')

        for y in range(10):
            cf.commander.send_hover_setpoint(0, 0, 0, y / 25)
            #cf.commander.send_stop_setpoint()
            time.sleep(0.1)

        for _ in range(50):
            cf.commander.send_hover_setpoint(0, 0, 0, 0.5)
            #cf.commander.send_stop_setpoint()
            time.sleep(0.1)

        print('Switching to LQR!')
        cf.param.set_value('stabilizer.controller', '3')

        with SyncLogger(scf, lg_stab) as logger:
            t_start = time.time()
            entry_count = 0

            for log_entry in logger:
                cf.commander.send_hover_setpoint(0, 0, 0, 0.5)
                for key, value in log_entry[1].items():
                    lg_data[key.split('.')[1]].append(value)

                entry_count += 1

                if time.time() - t_start > 5:
                    break

        print('Saving data...')
        for key in lg_data.keys():
            lg_data[key] = np.array(lg_data[key])

        np.savez('quad_data/quad_traj', **lg_data)

        print('Switching to PID!')
        cf.param.set_value('stabilizer.controller', '1')

        for _ in range(60):
            cf.commander.send_hover_setpoint(0, 0, 0, 0.5)
            time.sleep(0.1)

        for y in range(10):
            cf.commander.send_hover_setpoint(0, 0, 0, (10 - y) / 25)
            time.sleep(0.1)

        for i in range(10):
            cf.commander.send_stop_setpoint()
            time.sleep(0.1)

print('Done!')
# Out:
# Loaded LQR gain matrix.
# Initializing as PID
# Reset Kalman filter.
# Taking off!
# Switching to LQR!
# Saving data...
# Switching to PID!
# Done!

# %% [markdown]
# Finally, this cell plots the result of your physical experiments, i.e. the data logged by the most recent run of `run_lab1.py` in `quad_data/quad_traj.npz`. If you run it before flying the quadrotor, it will error since there is currently no flight data present. The output of the next cell _must_ be included in the notebook when you submit.

# %%
import os

if os.path.isfile('quad_data/quad_traj.npz'):
    npzfile = np.load('quad_data/quad_traj.npz')

    plt.rcParams["figure.figsize"] = (16,8)
    fig = plt.figure()

    ax = fig.add_subplot(311, title='Position')
    ax.plot(npzfile['e_x'][:125], label='x')
    ax.plot(npzfile['e_y'][:125], label='y')
    ax.legend()

    ax = fig.add_subplot(312, title='Angles')
    ax.plot(npzfile['e_roll'][:125], label='phi')
    ax.plot(npzfile['e_pitch'][:125], label='theta')
    ax.legend()

    ax = fig.add_subplot(313, title='Moments')
    ax.plot(npzfile['u2_pwm'][:125] / (2 ** 15), label='M1')
    ax.plot(npzfile['u3_pwm'][:125] / (2 ** 15), label='M2')
    ax.legend()
else:
    print('No flight data found.')

# %%
print(npzfile['e_x'][:125])
print(npzfile['e_y'][:125])
# Out:
# [ 0.0736983   0.07355956  0.07422578  0.07323705  0.07111112  0.07290079
#   0.07009114  0.06839523  0.07037655  0.06879106  0.06589949  0.06339686
#   0.0671206   0.06332389  0.0603764   0.06400032  0.05967693  0.05808167
#   0.06213141  0.05867765  0.056479    0.05393647  0.05532458  0.05344951
#   0.0503836   0.04945161  0.0473762   0.0455406   0.04163784  0.03347988
#   0.03591494  0.02884388  0.02051509  0.0193215   0.01694797  0.01149184
#   0.01016649  0.007663   -0.00760287 -0.01212015 -0.01316492 -0.01484707
#  -0.03562029 -0.03785901 -0.03954217 -0.06315064 -0.0626561  -0.06613053
#  -0.08615777 -0.08317214 -0.08632573 -0.08728723 -0.10644778 -0.10910501
#  -0.11129214 -0.12591074 -0.12728192 -0.12981904 -0.1434485  -0.14473195
#  -0.14673223 -0.15030406 -0.15926102 -0.16535947 -0.16814841 -0.175551
#  -0.17990109 -0.18372262 -0.1877854  -0.19299397 -0.19447096 -0.19699807
#  -0.19782697 -0.19918209 -0.20319708 -0.2001386  -0.20215628 -0.20498309
#  -0.19845322 -0.20027189 -0.20298104 -0.20606734 -0.19719984 -0.20075512
#  -0.20412023 -0.19372836 -0.19548216 -0.19842693 -0.18536784 -0.18881066
#  -0.19125131 -0.19247468 -0.18145818 -0.18344285 -0.18632592 -0.17848924
#  -0.18008354 -0.18242307 -0.17393248 -0.17689139 -0.17496474 -0.17530257
#  -0.17290512 -0.17440343 -0.17499091 -0.17156683 -0.17167175 -0.170885
#  -0.17242458 -0.17124788 -0.17294277 -0.17201149 -0.17525534 -0.17245436
#  -0.17606553 -0.18227018 -0.18285643 -0.18275934 -0.1906389  -0.18900587
#  -0.18919729 -0.19077487 -0.19824257 -0.19910419 -0.1989397 ]
# [-0.07049044 -0.0715856  -0.07235486 -0.07282588 -0.07146687 -0.07068262
#  -0.07164228 -0.07052449 -0.07088343 -0.070432   -0.06926275 -0.0676031
#  -0.06999005 -0.06747039 -0.06594075 -0.06873367 -0.06732026 -0.06483275
#  -0.0668838  -0.06590888 -0.06491851 -0.06205371 -0.06327651 -0.06082393
#  -0.05941258 -0.05863158 -0.05783183 -0.05668594 -0.05443342 -0.0503483
#  -0.05340827 -0.04713844 -0.03959826 -0.03881586 -0.03747772 -0.03307589
#  -0.03394102 -0.03159444 -0.02342579 -0.0212287  -0.01978501 -0.01962954
#  -0.00843648 -0.0081563  -0.00782128  0.00661671  0.0073678   0.00754657
#   0.01800399  0.01623287  0.01758148  0.01930386  0.02773874  0.02968417
#   0.03233804  0.03879506  0.0417215   0.04404778  0.04996379  0.05102586
#   0.05286252  0.05713673  0.06176599  0.06369238  0.06658906  0.06963276
#   0.07349379  0.07791533  0.07892501  0.08025969  0.08600771  0.08993434
#   0.0898485   0.09169782  0.09309458  0.09317905  0.09659008  0.09944397
#   0.10062533  0.10251166  0.10370553  0.1064153   0.10755351  0.10885561
#   0.10955086  0.11065244  0.11000031  0.11062656  0.11395895  0.11364961
#   0.11107226  0.11379837  0.11686756  0.11700462  0.11860663  0.12240724
#   0.12212253  0.12329495  0.12672666  0.12781125  0.12775703  0.12626095
#   0.1296481   0.13159736  0.13235025  0.13644443  0.13640498  0.13807064
#   0.13981436  0.13942458  0.14171334  0.14322032  0.14460121  0.14432788
#   0.14619596  0.14680393  0.14825501  0.14991811  0.149657    0.14932491
#   0.15144652  0.15349184  0.14984128  0.14962764  0.15221319]
